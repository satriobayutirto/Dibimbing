# %%
array1 = [1, 2, 3, 4, 5]
array2 = [2, 20, 30, 40, 50]
for i in range(len(array1)):
    array2[i] -= 1
    array1.append(array2[i])

# array1 now contains the combined and modified values
print(array1)
# Out:
# [1, 2, 3, 4, 5, 1, 19, 29, 39, 49]

# %%
def merge(nums1, m, nums2, n):
    i, j, k = m-1, n-1, m+n-1

    while i >= 0 and j >= 0:
        if nums1[i] > nums2[j]:
            nums1[k] = nums1[i]
            i -= 1
        else:
            nums1[k] = nums2[j]
            j -= 1
        k -= 1

    # If there are remaining elements in nums2, copy them to nums1
    while j >= 0:
        nums1[k] = nums2[j]
        j -= 1
        k -= 1

# Example usage
nums1 = [1, 2, 3, 0, 0, 0]
m = 3
nums2 = [2, 5, 6]
n = 3

merge(nums1, m, nums2, n)
print(nums1)
# Out:
# [1, 2, 2, 3, 5, 6]

# %%
def merge(nums1, m, nums2, n):
    i, j, k = m-1, n-1, m+n-1

    while i >= 0 and j >= 0:
        if nums1[i] > nums2[j]:
            nums1[k] = nums1[i]
            i -= 1
        else:
            nums1[k] = nums2[j]
            j -= 1
        k -= 1

    # If there are remaining elements in nums2, copy them to nums1
    while j >= 0:
        nums1[k] = nums2[j]
        j -= 1
        k -= 1

# Example usage
nums1 = [1, 2, 3, 0, 0, 0]
m = 3
nums2 = [2, 5, 6]
n = 3

merge(nums1, m, nums2, n)
print(nums1)
# Out:
# [1, 2, 2, 3, 5, 6]

# %%
nums1 = [1,2,3,0,0,0], m = 3, nums2 = [2,5,6], n =3
        nums1[m:] = nums2[:n]
        nums1.sort()
# Out:
#   File "<ipython-input-10-efed769ae6a4>", line 1
#     nums1 = [1,2,3,0,0,0], m = 3, nums2 = [2,5,6], n =3
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
def group_anagrams(strs):
    anagram_groups = {}

    for word in strs:
        # Sort the characters in the word to create a unique key
        sorted_word = ''.join(sorted(word))

        # Check if the key is already in the dictionary
        if sorted_word in anagram_groups:
            anagram_groups[sorted_word].append(word)
        else:
            # If the key is not in the dictionary, create a new entry
            anagram_groups[sorted_word] = [word]

    return list(anagram_groups.values())

# Example usage
strs1 = ["eat", "tea", "tan", "ate", "nat", "bat"]
result1 = group_anagrams(strs1)
print(result1)

strs2 = [""]
result2 = group_anagrams(strs2)
print(result2)

strs3 = ["a"]
result3 = group_anagrams(strs3)
print(result3)
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]
# [['']]
# [['a']]
