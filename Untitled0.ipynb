# %%
name= 'satrio bayu'

# %%
age=24

# %%
has_android= True

# %%
person=[name,age,has_android]
print("{} is aged {}, and owns an {}." 
    .format(person[0],person[1],
    "Android phone" if person[has_android] else "iPhone"))
# Out:
# satrio bayu is aged 24, and owns an Android phone.

# %%
color='white'
pet= 0
have_previous_programming_exp=True

my_list = [color,pet,have_previous_programming_exp]


print('My favorite color is',color)
print('I have {} pet(s).'.format(my_list[1]))
if have_previous_programming_exp == True :
    print("I have previous programming experience")
else:
    print("I do not have previous programming experience")
# Out:
# My favorite color is white
# I have 0 pet(s).
# I have previous programming experience

# %%
fav_number=88
my_list. append(fav_number)

# %%
print(my_list)
# Out:
# [0, True, 88]

# %%
my_list.pop(0)
# Out:
# 'white'

# %%
print("The list has {} elements.".format(sum(my_list)))
# Out:
# The list has 89 elements.

# %%
from IPython.lib.display import ScribdDocument


X = 18
while X<=534:
  X = X+1
  
if X % 7 == 0:
 sum_of_numbers= sum(X)
print('The sum of all the numbers divisible by 7 between 18 and 534 is', sum_of_numbers)
# Out:
# The sum of all the numbers divisible by 7 between 18 and 534 is 0

# %%
list_1 = [13, 14, 87, 44, 70, 9]

result = list (filter (lambda x: (x % 7 == 0), list_1))

print ('Numbers that are divisible by 7 are:', result)
# Out:
# Numbers that are divisible by 7 are: [14, 70]
