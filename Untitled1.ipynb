# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Series

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s

# %%
s=pd.Series([1,2,5, np.nan,8,9])
s

# %% [markdown]
# Dataframe

# %%
dates=pd.date_range('20150101',periods=7)
dates
df = pd.DataFrame(np.random.randn(7,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2015-01-01  0.279181 -0.672010  0.939881 -0.482822
# 2015-01-02  0.245182  0.519026  0.896013  0.353589
# 2015-01-03 -0.204098  0.739778  1.354953 -0.367889
# 2015-01-04 -0.844514 -0.155208 -0.636917  1.741752
# 2015-01-05 -1.795585 -0.076214 -1.616417 -0.287935
# 2015-01-06  0.533496 -0.100178  0.384143 -1.405464
# 2015-01-07 -0.808122 -0.252275  0.098611 -1.444984

# %%
df2=pd.DataFrame({
    'a': 1.0,
    'b':pd.Timestamp('20130102'),
    'c':np.array([3]*4,dtype='int32'),
    'd':pd.Series(1,index=list(range(4)),dtype='float32'),
    'e':pd.Categorical(['test','train','test','trsin']),
    'f':'foo',
})
df2
# Out:
#      a          b  c    d      e    f
# 0  1.0 2013-01-02  3  1.0   test  foo
# 1  1.0 2013-01-02  3  1.0  train  foo
# 2  1.0 2013-01-02  3  1.0   test  foo
# 3  1.0 2013-01-02  3  1.0  trsin  foo
