# %%
pip install pandasql
# Out:
# Collecting pandasql
#   Downloading pandasql-0.7.3.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pandasql) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pandasql) (1.5.3)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.10/dist-packages (from pandasql) (2.0.24)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandasql) (2023.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy->pandasql) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy->pandasql) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->pandasql) (1.16.0)
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (setup.py) ... done
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26772 sha256=373b62b4653d5f21f7b7547429eedd5e6f89d675a8bd775093c8a67e50fa5bbc
#   Stored in directory: /root/.cache/pip/wheels/e9/bc/3a/8434bdcccf5779e72894a9b24fecbdcaf97940607eaf4bcdf9
# Successfully built pandasql
# Installing collected packages: pandasql
# Successfully installed pandasql-0.7.3

# %%
from pandasql import sqldf
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
file_dirs = "/content/drive/MyDrive/Colab Notebooks/Extra Class/sql"
os.chdir(file_dirs)

# %%
worldcity = pd.read_csv('worldcities.csv', sep = ';', encoding = 'latin-1')
uscity = pd.read_csv('uscities.csv', sep = ';', encoding = 'latin-1')
uscity.columns = ['city', 'state_id', 'state_name', 'county_fips', 'county_name',
       'lat', 'lng', 'population', 'density', 'source', 'military',
       'incorporated', 'timezone', 'ranking', 'zips', 'id']

# %%
worldcity
# Out:
#               city      lat       lng      country iso2 iso3  capital  \
# 0            Tokyo  35.6897  139.6922        Japan   JP  JPN  primary
# 1          Jakarta  -6.2146  106.8451    Indonesia   ID  IDN  primary
# 2            Delhi  28.6600   77.2300        India   IN  IND    admin
# 3           Mumbai  18.9667   72.8333        India   IN  IND    admin
# 4           Manila  14.6000  120.9833  Philippines   PH  PHL  primary
# ...            ...      ...       ...          ...  ...  ...      ...
# 40996       Tukchi  57.3670  139.5000       Russia   RU  RUS      NaN
# 40997        Numto  63.6667   71.3333       Russia   RU  RUS      NaN
# 40998         Nord  81.7166  -17.8000    Greenland   GL  GRL      NaN
# 40999  Timmiarmiut  62.5333  -42.2167    Greenland   GL  GRL      NaN
# 41000      Nordvik  74.0165  111.5100       Russia   RU  RUS      NaN
#
#        population          id
# 0      37977000.0  1392685764
# 1      34540000.0  1360771077
# 2      29617000.0  1356872604
# 3      23355000.0  1356226629
# 4      23088000.0  1608618140
# ...           ...         ...
# 40996        10.0  1643472801
# 40997        10.0  1643985006
# 40998        10.0  1304217709
# 40999        10.0  1304206491
# 41000         0.0  1643587468
#
# [41001 rows x 9 columns]

# %%
import seaborn as sns
worldcity2 = sns.load_dataset('worldcities.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-5a0ea95c23d2> in <cell line: 2>()
#       1 import seaborn as sns
# ----> 2 worldcity2 = sns.load_dataset('worldcities.csv')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     571         if not os.path.exists(cache_path):
#     572             if name not in get_dataset_names():
# --> 573                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     574             urlretrieve(url, cache_path)
#     575         full_path = cache_path
#
# ValueError: 'worldcities.csv' is not one of the example datasets.

# %%
data = {'city': ['CityA', 'CityB', 'CityC'],
        'lat': [35, 38, 36],
        'lng': [110, 120, 130],
        'capital': ['primary', 'primary', 'secondary'],
        'population': [25000000, 18000000, 22000000]}

# %%
df = pd.DataFrame(data)

# %%
query = """
SELECT DISTINCT city
FROM df
WHERE lat BETWEEN 33 AND 40
AND lng BETWEEN 100 AND 140
AND capital = 'primary'
AND population > 20000000
"""

sqldf(query, env=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in execute(self, statement, parameters, execution_options)
#    1411         try:
# -> 1412             meth = statement._execute_on_connection
#    1413         except AttributeError as err:
#
# AttributeError: 'str' object has no attribute '_execute_on_connection'
#
# The above exception was the direct cause of the following exception:
#
# ObjectNotExecutableError                  Traceback (most recent call last)
# <ipython-input-20-e6e64720f6bf> in <cell line: 10>()
#       8 """
#       9
# ---> 10 sqldf(query, env=None)
#
# /usr/local/lib/python3.10/dist-packages/pandasql/sqldf.py in sqldf(query, env, db_uri)
#     154     >>> sqldf("select avg(x) from df;", locals())
#     155     """
# --> 156     return PandaSQL(db_uri)(query, env)
#
# /usr/local/lib/python3.10/dist-packages/pandasql/sqldf.py in __call__(self, query, env)
#      59
#      60             try:
# ---> 61                 result = read_sql(query, conn)
#      62             except DatabaseError as ex:
#      63                 raise PandaSQLException(ex)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     588         )
#     589     else:
# --> 590         return pandas_sql.read_query(
#     591             sql,
#     592             index_col=index_col,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1558         args = _convert_params(sql, params)
#    1559
# -> 1560         result = self.execute(*args)
#    1561         columns = result.keys()
#    1562
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1403     def execute(self, *args, **kwargs):
#    1404         """Simple passthrough to SQLAlchemy connectable"""
# -> 1405         return self.connectable.execution_options().execute(*args, **kwargs)
#    1406
#    1407     def read_table(
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in execute(self, statement, parameters, execution_options)
#    1412             meth = statement._execute_on_connection
#    1413         except AttributeError as err:
# -> 1414             raise exc.ObjectNotExecutableError(statement) from err
#    1415         else:
#    1416             return meth(
#
# ObjectNotExecutableError: Not an executable object: "\nSELECT DISTINCT city\nFROM df\nWHERE lat BETWEEN 33 AND 40\nAND lng BETWEEN 100 AND 140\nAND capital = 'primary'\nAND population > 20000000\n"

# %%
sqldf('''SELECT city, country
FROM worldicty
LIMIT 5''')

sql_run(query)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in execute(self, statement, parameters, execution_options)
#    1411         try:
# -> 1412             meth = statement._execute_on_connection
#    1413         except AttributeError as err:
#
# AttributeError: 'str' object has no attribute '_execute_on_connection'
#
# The above exception was the direct cause of the following exception:
#
# ObjectNotExecutableError                  Traceback (most recent call last)
# <ipython-input-15-30f23816f05f> in <cell line: 1>()
# ----> 1 sqldf('''SELECT city, country
#       2 FROM worldicty
#       3 LIMIT 5''')
#       4
#       5 sql_run(query)
#
# /usr/local/lib/python3.10/dist-packages/pandasql/sqldf.py in sqldf(query, env, db_uri)
#     154     >>> sqldf("select avg(x) from df;", locals())
#     155     """
# --> 156     return PandaSQL(db_uri)(query, env)
#
# /usr/local/lib/python3.10/dist-packages/pandasql/sqldf.py in __call__(self, query, env)
#      59
#      60             try:
# ---> 61                 result = read_sql(query, conn)
#      62             except DatabaseError as ex:
#      63                 raise PandaSQLException(ex)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     588         )
#     589     else:
# --> 590         return pandas_sql.read_query(
#     591             sql,
#     592             index_col=index_col,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1558         args = _convert_params(sql, params)
#    1559
# -> 1560         result = self.execute(*args)
#    1561         columns = result.keys()
#    1562
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1403     def execute(self, *args, **kwargs):
#    1404         """Simple passthrough to SQLAlchemy connectable"""
# -> 1405         return self.connectable.execution_options().execute(*args, **kwargs)
#    1406
#    1407     def read_table(
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in execute(self, statement, parameters, execution_options)
#    1412             meth = statement._execute_on_connection
#    1413         except AttributeError as err:
# -> 1414             raise exc.ObjectNotExecutableError(statement) from err
#    1415         else:
#    1416             return meth(
#
# ObjectNotExecutableError: Not an executable object: 'SELECT city, country\t \nFROM worldicty \nLIMIT 5'

# %%
sqldf(query, env=None)
