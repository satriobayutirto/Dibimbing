# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Manipulation with Pandas - Hands On

# %% [markdown]
# ### I. Create DataFrame

# %% [markdown]
# Kita bisa membuat dataframe dengan menuliskan dictionary seperti ini.

# %%
dictionary_satu = {
    "cust_id": ['A1','A2','A3','A4','A5'],
    "item_bought": [10,15,20,35,4],
    "city": ['Bandung', 'Surabaya', 'Bekasi', 'Tangerang', 'Denpasar']
}
''' cist_id = colomg, [sdweqe]=list'''
# Out:
# ' cist_id = colomg, [sdweqe]=list'

# %%
tabel = pd.DataFrame(dictionary_satu)

# %%
tabel
# Out:
#   cust_id  item_bought       city
# 0      A1           10    Bandung
# 1      A2           15   Surabaya
# 2      A3           20     Bekasi
# 3      A4           35  Tangerang
# 4      A5            4   Denpasar

# %%
df = pd.DataFrame(
    {
    "cust_id": ['A1','A2','A3','A4','A5'],
    "item_bought": [10,15,20,35,4],
    "city": ['Bandung', 'Surabaya', 'Bekasi', 'Tangerang', 'Denpasar']
}
)

df
# Out:
#   cust_id  item_bought       city
# 0      A1           10    Bandung
# 1      A2           15   Surabaya
# 2      A3           20     Bekasi
# 3      A4           35  Tangerang
# 4      A5            4   Denpasar

# %% [markdown]
# ### II. Basic Pandas Operation

# %% [markdown]
# #### II.1. Basic

# %% [markdown]
# Basic overviews:

# %%
df.info() '''object=bukan bilangan '''
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cust_id      5 non-null      object
#  1   item_bought  5 non-null      int64
#  2   city         5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 248.0+ bytes

# %% [markdown]
# covert 64 ke 16 blm signifikan= harus datanya banyak, load berat dengan nilain tidak lebih dari kapasitas 16 bit

# %%
df['item_bought'] = df['item_bought'].astype('int16')

# %%
df.describe()
# Out:
#        item_bought
# count     5.000000
# mean     16.800000
# std      11.777096
# min       4.000000
# 25%      10.000000
# 50%      15.000000
# 75%      20.000000
# max      35.000000

# %%
df.columns
# Out:
# Index(['cust_id', 'item_bought', 'city'], dtype='object')

# %%
df
# Out:
#   cust_id  item_bought       city
# 0      A1           10    Bandung
# 1      A2           15   Surabaya
# 2      A3           20     Bekasi
# 3      A4           35  Tangerang
# 4      A5            4   Denpasar

# %% [markdown]
# **Changing** column names(multiple):

# %%
df.columns = ['cust_id', 'quantity', 'center_city']

# %%
df
# Out:
#   cust_id  quantity center_city
# 0      A1        10     Bandung
# 1      A2        15    Surabaya
# 2      A3        20      Bekasi
# 3      A4        35   Tangerang
# 4      A5         4    Denpasar

# %% [markdown]
# mengubah single judul kolom
# khusus untuk judul colomnya saja bukan utk isinya

# %%
df = df.rename({'center_city':'tempat'}, axis = 'columns')
df = df.rename({'quantity':'jumlah'},axis = 'columns')

# %% [markdown]
# mengganti isi (tidak dianjurkan karena melenceng dari tujuan panda yaitu exploratory data posis yg diganti = [baris,kolom]

# %%
df.iloc[0,2] = "Yogyakarta"
df.loc[1,'cust_id'] ="B2"

# %%
df
# Out:
#   cust_id  jumlah      tempat
# 0      A1      10  Yogyakarta
# 1      B2      15    Surabaya
# 2      A3      20      Bekasi
# 3      A4      35   Tangerang
# 4      A5       4    Denpasar

# %% [markdown]
# DataFrame shape (row, column)

# %%
df.shape
# Out:
# (5, 3)

# %% [markdown]
# #### II.2. Filtering

# %% [markdown]
# Selecting first few rows

# %%
df.head(2)
# Out:
#   cust_id  jumlah      tempat
# 0      A1      10  Yogyakarta
# 1      B2      15    Surabaya

# %% [markdown]
# Selecting last rows

# %%
df.tail(3)
# Out:
#   cust_id  jumlah     tempat
# 2      A3      20     Bekasi
# 3      A4      35  Tangerang
# 4      A5       4   Denpasar

# %% [markdown]
# Saving to csv

# %%
df
# Out:
#   cust_id  jumlah      tempat
# 0      A1      10  Yogyakarta
# 1      B2      15    Surabaya
# 2      A3      20      Bekasi
# 3      A4      35   Tangerang
# 4      A5       4    Denpasar

# %%
# Saving
df.to_csv('backup.csv', index = False) '''biar ga ada index phyton 0,1,2,....'''

# %%
df
# Out:
#   cust_id  jumlah      tempat
# 0      A1      10  Yogyakarta
# 1      B2      15    Surabaya
# 2      A3      20      Bekasi
# 3      A4      35   Tangerang
# 4      A5       4    Denpasar

# %% [markdown]
# Menambahkan kolom 'gender' sehingga kolom 'gender' ini berada di urutan index ke-2

# %%
#menanbahkan kolom jender
df.insert(loc=2, column='gender', value=['male', 'female', 'female', 'female', 'male'])

# %%
#menambahkan kolom barang
barang = ['Laptop', 'Baju', 'Headset', 'Dompet', 'Botol Minum']
df.insert(loc = 1, column = 'barang', value = barang)

# %%
df
# Out:
#   cust_id       barang  jumlah  gender      tempat
# 0      A1       Laptop      10    male  Yogyakarta
# 1      B2         Baju      15  female    Surabaya
# 2      A3      Headset      20  female      Bekasi
# 3      A4       Dompet      35  female   Tangerang
# 4      A5  Botol Minum       4    male    Denpasar

# %% [markdown]
# Selecting specific columns only

# %%
tabel_pilihan = df[['cust_id', 'tempat']]

# %%
tabel_pilihan
# Out:
#   cust_id      tempat
# 0      A1  Yogyakarta
# 1      B2    Surabaya
# 2      A3      Bekasi
# 3      A4   Tangerang
# 4      A5    Denpasar

# %% [markdown]
# Filtering rows that has quantity > 10

# %%
syarat = df['jumlah'] > 10

df[syarat]
# Out:
#   cust_id   barang  jumlah  gender     tempat
# 1      B2     Baju      15  female   Surabaya
# 2      A3  Headset      20  female     Bekasi
# 3      A4   Dompet      35  female  Tangerang

# %%
df[ df['jumlah'] > 10 ]
# Out:
#   cust_id   barang  jumlah  gender     tempat
# 1      B2     Baju      15  female   Surabaya
# 2      A3  Headset      20  female     Bekasi
# 3      A4   Dompet      35  female  Tangerang

# %% [markdown]
# Filtering rows that has quantity >= 10 and whose 'tempat' is in Bandung / Surabaya / Tangerang

# %%
syarat_1 = df['jumlah'] >= 10
syarat_2 = df['tempat'].isin(['Yogyakarta', 'Surabaya', 'Tangerang'])

df[ syarat_1 & syarat_2 ]
# Out:
#   cust_id  barang  jumlah  gender      tempat
# 0      A1  Laptop      10    male  Yogyakarta
# 1      B2    Baju      15  female    Surabaya
# 3      A4  Dompet      35  female   Tangerang

# %%
syarat_1 = df['gender'] == 'male'
syarat_2 = df['barang'].isin(['Laptop', 'Headset'])
df[ syarat_1 & syarat_2 ]
# Out:
#   cust_id  barang  jumlah gender      tempat
# 0      A1  Laptop      10   male  Yogyakarta

# %%
# inefficient programming

syarat_1 = df['jumlah'] >= 10
syarat_2 = df['tempat'] == 'Yogyakarta'
syarat_3 = df['tempat'] == 'Surabaya'
syarat_4 = df['tempat'] == 'Tangerang'

df[ syarat_1 & (syarat_2 | syarat_3 | syarat_4)]
# Out:
#   cust_id  barang  jumlah  gender     tempat
# 1      B2    Baju      15  female   Surabaya
# 3      A4  Dompet      35  female  Tangerang

# %% [markdown]
# ### Replacing Columns in a Filtered Data

# %%
df
# Out:
#   cust_id       barang  jumlah  gender      tempat
# 0      A1       Laptop      10    male  Yogyakarta
# 1      B2         Baju      15  female    Surabaya
# 2      A3      Headset      20  female      Bekasi
# 3      A4       Dompet      35  female   Tangerang
# 4      A5  Botol Minum       4    male    Denpasar

# %%
df_edit = df.copy()
df_edit
# Out:
#   cust_id       barang  jumlah  gender      tempat
# 0      A1       Laptop      10    male  Yogyakarta
# 1      B2         Baju      15  female    Surabaya
# 2      A3      Headset      20  female      Bekasi
# 3      A4       Dompet      35  female   Tangerang
# 4      A5  Botol Minum       4    male    Denpasar

# %% [markdown]
# Untuk semua customer yang quantity nya lebih dari 10, ubah 'tempat' mereka jadi "Jakarta"

# %%
condition = df_edit['jumlah'] > 10

df_edit.loc[condition, 'tempat'] = 'Jakarta'

# %%
df_edit
# Out:
#   cust_id       barang  jumlah  gender      tempat
# 0      A1       Laptop      10    male  Yogyakarta
# 1      B2         Baju      15  female     Jakarta
# 2      A3      Headset      20  female     Jakarta
# 3      A4       Dompet      35  female     Jakarta
# 4      A5  Botol Minum       4    male    Denpasar

# %% [markdown]
# Index ke-0, 1, 2 dari Customer ID, ubah kode nya jadi 'B1', 'B2', 'B3'

# %%
df_edit.loc[0:2,'cust_id'] = ['B1', 'B2', 'B3']

# %%
df_edit
# Out:
#   cust_id       barang  jumlah  gender      tempat
# 0      B1       Laptop      10    male  Yogyakarta
# 1      B2         Baju      15  female     Jakarta
# 2      B3      Headset      20  female     Jakarta
# 3      A4       Dompet      35  female     Jakarta
# 4      A5  Botol Minum       4    male    Denpasar

# %%
df_edit
# Out:
#   cust_id       barang  jumlah  gender      tempat
# 0      B1       Laptop      10    male  Yogyakarta
# 1      B2         Baju      15  female     Jakarta
# 2      B3      Headset      20  female     Jakarta
# 3      A4       Dompet      35  female     Jakarta
# 4      A5  Botol Minum       4    male    Denpasar

# %% [markdown]
# Kalau yang quantity nya > 15 atau < 5, maka, tempat nya kita ganti ke 'Warehouse'

# %%
condition_1 = df_edit['jumlah'] > 15
condition_2 = df_edit['jumlah'] < 5

condition = condition_1 | condition_2

df_edit.loc[condition, 'tempat'] = 'Warehouse'

# %%
df_edit
# Out:
#   cust_id       barang  jumlah  gender      tempat
# 0      B1       Laptop      10    male  Yogyakarta
# 1      B2         Baju      15  female     Jakarta
# 2      B3      Headset      20  female   Warehouse
# 3      A4       Dompet      35  female   Warehouse
# 4      A5  Botol Minum       4    male   Warehouse

# %%
df
# Out:
#   cust_id       barang  jumlah  gender      tempat
# 0      A1       Laptop      10    male  Yogyakarta
# 1      B2         Baju      15  female    Surabaya
# 2      A3      Headset      20  female      Bekasi
# 3      A4       Dompet      35  female   Tangerang
# 4      A5  Botol Minum       4    male    Denpasar

# %% [markdown]
# Filtering with OR conditionals

# %%
df[df['jumlah'] > 15]
# Out:
#   cust_id   barang  jumlah  gender     tempat
# 2      A3  Headset      20  female     Bekasi
# 3      A4   Dompet      35  female  Tangerang

# %%
df[df['tempat'] != 'Tangerang']
# Out:
#   cust_id       barang  jumlah  gender      tempat
# 0      A1       Laptop      10    male  Yogyakarta
# 1      B2         Baju      15  female    Surabaya
# 2      A3      Headset      20  female      Bekasi
# 4      A5  Botol Minum       4    male    Denpasar

# %%
df[(df["jumlah"]>15) | (df["tempat"] != "Tangerang")]
# Out:
#   cust_id       barang  jumlah  gender      tempat
# 0      A1       Laptop      10    male  Yogyakarta
# 1      B2         Baju      15  female    Surabaya
# 2      A3      Headset      20  female      Bekasi
# 3      A4       Dompet      35  female   Tangerang
# 4      A5  Botol Minum       4    male    Denpasar

# %% [markdown]
# Saving a filtered dataframe

# %%
df_more_than_10 = df[df['jumlah']>10]

# %%
df_more_than_10
# Out:
#   cust_id   barang  jumlah  gender     tempat
# 1      B2     Baju      15  female   Surabaya
# 2      A3  Headset      20  female     Bekasi
# 3      A4   Dompet      35  female  Tangerang

# %%
kolom_dihapus = ['cust_id', 'barang']
df_edit.drop (kolom_dihapus, axis = 'columns',inplace = True)'''inplace = True, langsung diaplikasikan tanpai ini cuman ditampilkan review doang'''
# Out:
#    jumlah  gender      tempat
# 0      10    male  Yogyakarta
# 1      15  female     Jakarta
# 2      20  female   Warehouse
# 3      35  female   Warehouse
# 4       4    male   Warehouse

# %% [markdown]
# Restore the index

# %%
df_more_than_10 = df[df['jumlah']>10].reset_index(drop = True)

# %%
df_more_than_10
# Out:
#   cust_id   barang  jumlah  gender     tempat
# 0      B2     Baju      15  female   Surabaya
# 1      A3  Headset      20  female     Bekasi
# 2      A4   Dompet      35  female  Tangerang

# %% [markdown]
# Resample random rows >> run the cell below several times and you'll get different results.

# %%
df.sample(3)
# Out:
#   cust_id       barang  jumlah  gender      tempat
# 0      A1       Laptop      10    male  Yogyakarta
# 3      A4       Dompet      35  female   Tangerang
# 4      A5  Botol Minum       4    male    Denpasar

# %% [markdown]
# #### II.3. Reorder Columns

# %%
df

# %%
df_reorder = df[['quantity', 'tempat', 'cust_id']]

# %%
df_reorder

# %% [markdown]
# ### III. Group-By Data

# %%
iris = pd.read_csv("https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/639388c2cbc2120a14dcf466e85730eb8be498bb/iris.csv")

# %%
iris

# %%
iris['species'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3533f6942886> in <cell line: 1>()
# ----> 1 iris['species'].unique()
#
# NameError: name 'iris' is not defined

# %%
iris['species'].value_counts()

# %%
iris

# %% [markdown]
# First, we can do `value_counts` to know how much species are there in the whole dataset.

# %%
iris['species'].value_counts()

# %%
iris['species'].value_counts(normalize = True)

# %%
iris['species'].nunique()

# %% [markdown]
# Next, we can groupby each species and find out a few important things!

# %%
iris.groupby('species').min()

# %%
iris.groupby('species').max() #to know the maximum length/width of the flowers in each species
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3efa3be93e50> in <cell line: 1>()
# ----> 1 iris.groupby('species').max() #to know the maximum length/width of the flowers in each species
#
# NameError: name 'iris' is not defined

# %%
iris.groupby('species').min()

# %% [markdown]
# However, we can specify in details what we want to get from each columns, as such:

# %%
# bikin dulu aggregation dictionary
aggregation_dictionary = {
    'sepal_length': ['max', 'min', 'mean'],
     'sepal_width': ['max', 'min', 'mean'],
     'petal_length': ['median', 'max', 'min', 'mean', 'count']
}

# groupby using aggregation
iris.groupby('species').agg(aggregation_dictionary)

# %%
groupby_result = iris.groupby('species').agg(aggregation_dictionary)

# %%
groupby_result

# %% [markdown]
# Perhatikan! Index kolomnya itu 'multi-index', sehingga jika kita ingin memilih beberapa kolom saja, bentuknya harus seperti ini:

# %% [markdown]
# Contoh: saya ingin memanggil, "Sepal Length, Max" dan "Petal Length, Median". Nggak mau yang lain. Untuk Petal Length, saya tidak mau ambil Mean nya.

# %%
groupby_result[[ ('sepal_length', 'max')  , ('petal_length', 'median') ]]

# %%
iris.describe()

# %% [markdown]
# ### Order or Sorting

# %%
iris
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2975561be2ce> in <cell line: 1>()
# ----> 1 iris
#
# NameError: name 'iris' is not defined

# %% [markdown]
# Order by species, and then sepal length

# %%
iris.sort_values(['species', 'sepal_length'], ascending = [True, False]).reset_index(drop = True)

# %%
iris_sorted = iris.sort_values(['species', 'sepal_length'], ascending = [True, False]).reset_index(drop = True)

# %%
iris_sorted

# %%
tabel_ulangan = pd.DataFrame({
    'nama': ['Abdul', 'Aji', 'Budi', 'Delta', 'Eko', 'Charlie'],
    'nilai_ulangan': [90,90,70,70,80,85]
})

# %%
tabel_ulangan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e395bf92b9f9> in <cell line: 1>()
# ----> 1 tabel_ulangan
#
# NameError: name 'tabel_ulangan' is not defined

# %% [markdown]
# Urutkan dari nilai ulangan TERTINGGI ke TERRENDAH.
#
#
# Jika siswa memiliki nilai ulangan yang sama, urutkan dari ABJAD AWAL KE AKHIR

# %%
tabel_ulangan.sort_values(['nilai_ulangan', 'nama'], ascending = [False, True]).reset_index(drop = True)

# %% [markdown]
# - nilai_ulangan, ascending = False
# - nama, ascending = True

# %%
tabel_ulangan.sort_values(['nilai_ulangan', 'nama'], ascending = [False, True]).reset_index(drop = True)

# %%
tabel_ulangan['nilai_ulangan'].value_counts(normalize = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-91c9b67d03da> in <cell line: 1>()
# ----> 1 tabel_ulangan['nilai_ulangan'].value_counts(normalize = True)
#
# NameError: name 'tabel_ulangan' is not defined

# %% [markdown]
# ### IV. Date Time Manipulation

# %%
df = pd.DataFrame({
    'ID':[1,2,3,4,5,6],
    'Date':['2022/10/01', '2023/03/11', '2021/10/30', '2023/01/15', '2023/04/15', '2022/09/14']
})

# %%
df

# %%
df.info()

# %% [markdown]
# Mengubah kolom menjadi datetime

# %%
#df['Date'] = pd.to_datetime(df['Date'], format = '%Y/%m/%d')
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-eccf2ba8da79> in <cell line: 2>()
#       1 #df['Date'] = pd.to_datetime(df['Date'], format = '%Y/%m/%d')
# ----> 2 df['Date'] = pd.to_datetime(df['Date'])
#
# NameError: name 'pd' is not defined

# %%
df

# %%
df.info()

# %% [markdown]
# Memisahkan tahun, bulan, tanggal

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df['Day_Name'] = df['Date'].dt.day_name()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-40dd306a2157> in <cell line: 1>()
# ----> 1 df['Year'] = df['Date'].dt.year
#       2 df['Month'] = df['Date'].dt.month
#       3 df['Day'] = df['Date'].dt.day
#       4 df['Day_Name'] = df['Date'].dt.day_name()
#
# NameError: name 'df' is not defined

# %%
df

# %% [markdown]
# Beginning of Month, and End of Month

# %%
from dateutil.relativedelta import relativedelta

# %%
tanggal = pd.to_datetime('2023-08-13')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-5c704f2e41cd> in <cell line: 1>()
# ----> 1 tanggal = pd.to_datetime('2023-08-13')
#
# NameError: name 'pd' is not defined

# %%
tanggal

# %% [markdown]
# Tanggal Besoknya

# %%
tanggal + relativedelta(days = 1)

# %% [markdown]
# Bulan Depan

# %%
tanggal + relativedelta(months = 1)

# %% [markdown]
# Dua Bulan Silam

# %%
tanggal - relativedelta(months = 2)

# %%
### Awal Bulan
awal_bulan = tanggal.replace(day = 1)
awal_bulan

# %%
### Akhir Bulan

tanggal + relativedelta(day = 31)

# %%
df

# %%
df['Awal Bulan'] = [x.replace(day=1) for x in df['Date']]
df['Akhir Bulan'] = [x + relativedelta(day=31) for x in df['Date']]

# %%
df

# %% [markdown]
# How many day_name in a specific month

# %%
import calendar

# Ada berapa hari Sabtu dalam bulan April 2023?

# pertama kita masukin dulu tahun, bulan, dan hari yang kita ingin tahu berapa banyaknya
year = 2023
month = 4
day_to_count = calendar.SATURDAY

# kemudian kita buat matrix bulan tersebut
matrix = calendar.monthcalendar(year,month)

# %%
matrix

# %%
num_days = sum(1 for x in matrix if x[day_to_count] != 0)
num_days

# %% [markdown]
# How to know the current datetime

# %%
from datetime import datetime

# %%
datetime.today()

# %%
pd.to_datetime(datetime.today())

# %% [markdown]
# ### Extra: Cara Nge-Loop 1 Baris - List Comprehension

# %%
nilai_siswa = [80, 60, 75, 65, 90, 100, 55]

# %% [markdown]
# Kalau >= 70, LULUS, kalau < 70, REMEDIAL

# %%
# Cara looping biasa

kelulusan = []

for n in nilai_siswa:
    if n >= 70:
        kelulusan.append('Lulus')
    else:
        kelulusan.append('Remedial')

kelulusan

# %%
# cara satu baris

["Lulus" if n >=70 else "Remedial" for n in nilai_siswa]

# %%
# Contoh lain yang nggak pake if else

nilai_siswa = [80, 60, 75, 65, 90, 100, 55]

# Katrol nilainya dengan ditambahin 15, tapi kalau mentok 100, ya udh 100 aja

nilai_katrol = [min(100, x+15) for x in nilai_siswa]

# %%
nilai_katrol

# %% [markdown]
# ### V. Data Transformation

# %% [markdown]
# Kita bisa melakukan operasi kolom (atau baris) di dataframe menggunakan fitur `apply` pada `pandas`.

# %%
df = pd.DataFrame({ 'A': np.random.randint(low = 1, high = 10, size = 100),
                   'B': np.random.randint(low = 10, high = 100, size = 100),
                   'C': np.random.randint(low = 20, high = 45, size = 100)
                  }, )
df

# %% [markdown]
# Misal kita ingin membuat kolom baru, kolom 'D', dengan rumus sebagai berikut:
# - D = 10 * A + (0.5 * B) - Akar(C)

# %% [markdown]
# Maka bagaimana agar kita cukup menulis 1 fungsi saja, dan langsung bisa menghitung seluruh baris di dataframe kita?

# %%
df['D'] = 10 * df['A'] + (0.5 * df['B']) - np.sqrt(df['C'])

# %%
df

# %% [markdown]
# Nah, kalo kita cuma pengen tau rata-rata per barisnya gimana? Apakah perlu se-ribet itu? Nggak pastinya. Kalau operasinya itu yang umum-umum saja, tidak usah pakai `apply lambda`.

# %%
df['rata-rata_abc'] = df[['A','B','C']].mean(axis = 1)

# %%
df['standar_deviasi_abc'] = df[['A','B','C']].std(axis = 1)

# %%
df

# %%
rata_rata_kolom_a = df[['A']].mean(axis = 0)
rata_rata_kolom_a

# %% [markdown]
# Next, bagaimana jika kita ingin melakukan pemetaan? Misalnya:
# - Jika kolom A bernilai 1-3, kita beri label 'Kurang'
# - Jika kolom A bernilai 4-7, kita beri label 'Cukup'
# - Jika kolom A bernilai 8-10, kita beri label 'Surplus'

# %%
def label(a):
    if a<4:
        return 'Kurang'
    elif a<8:
        return 'Cukup'
    else:
        return 'Surplus'

# %%
df['label_A'] = df['A'].apply(label)

# %%
df

# %% [markdown]
# Nah, selain `apply`, sebenarnya ada juga yang namanya pemetaan menggunakan dictionary. Contohnya:

# %%
warna_harga = {
    'Kuning':15000,
    'Hijau':10000,
    'Biru':11000
}

df_laporan = pd.DataFrame({
    'Warna':['Kuning', 'Kuning', 'Hijau', 'Kuning', 'Biru', 'Biru', 'Kuning', 'Hijau'],
    'Kuantitas':[10,10,20,15,8,20,12,18]
})

# %%
df_laporan

# %%
df_laporan['harga_satuan'] = df_laporan['Warna'].map(warna_harga)

# %%
df_laporan

# %%
df_laporan['total_harga'] = df_laporan['Kuantitas'] * df_laporan['harga_satuan']

# %%
df_laporan

# %%
total_penjualan = df_laporan['total_harga'].sum(axis = 0)
total_penjualan

# %% [markdown]
# Fungsi untuk dua parameter

# %%
def fungsi_dua_parameter(a, b):
    if a < 4:
        if b < 50:
            return 'Sangat Kurang'
        else:
            return 'Kurang'
    elif a < 8:
        if b < 50:
            return 'Sedikit Cukup'
        else:
            return 'Cukup'
    else:
        if b < 50:
            return 'Banyak'
        else:
            return 'Surplus'

# %%
df['a_b'] = df.apply(lambda x: fungsi_dua_parameter(x['A'], x['B']), axis = 1)

# %%
df

# %% [markdown]
# ## Urutan Pengolahan Data di Data Science

# %% [markdown]
# 1. Ketika dapet datanya, explore dulu datanya. Ngertiin setiap kolom, artinya apa, dan data-type nya apa. Kalau ada data-type yang tidak sesuai, disesuaikan dulu. (Contoh: Angka tapi string, Datetime tapi object)
#
# 2. Pastikan temen-temen udh paham, ini dataset secara overall, ngomongin apa. Tujuannya apa dalam project ini. Data Type dari masing-masing kolom udah bener atau belom.
#
# 3. Check for missing value and outliers. At this point, ketika ketemu missing value dan outliers, laporkan ke orang yang ngasih data ke temen-temen
#
# 4. Discuss the best way to handle the missing value / outliers
#
# 5. Now, datanya udh bersih, nah, ini dieksplor lagi. Tapi, eksplorasi di tahap ini, lebih ke mendapatkan insight. Di sini, teman-teman akan plotting, visualize, dan coba untuk mengerti relasi antar kolom dalam data tabel.
#
# 6. Sebenarnya, kalau soal ngedapetin insight, ya udh selesai di tahap ini. Mungkin teman-teman bisa bikin dashboard / infographic yang dipresentasikan.
#
# 7. Kalau mau dilanjutin ke machine learning, mesti di-define dulu, apa tujuan dari machine learning ini? Kolom mana yang mau diprediksi? Apa output yang diharapkan dari machine learning?
#
# 8. Kalau udh fixed, silakan menyiapkan data 'training' dari machine learning tersebut. Cek juga asumsi-asumsi apa yang harus dipenuhi dari machine learning algorithm yang teman-teman akan pilih. Pastikan data kita memenuhi asumsi-asumsi tersebut. Pastikan juga, data kita numerik. Di sini teman-teman bisa melakukan encoding (onehot / rank) dan jika dibutuhkan, dilakukan standardisasi.
#
# 9. Validate the performance of your machine learning model
#
# 10. Try to improve the accuracy or metrics of your machine learning model sampe dirasa sudah 'ok'
#
# 11. Deploy machine learning model tersebut

# %% [markdown]
# ### VI. Data Standardization --> Machine Learning

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.violinplot(data = iris, x = 'species', y = 'sepal_length')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
iris['sepal_length'].mean(axis = 0)
# Out:
# 5.843333333333334

# %%
iris['sepal_length'].std(axis = 0)
# Out:
# 0.828066127977863

# %%
from sklearn import preprocessing

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
preprocessing.scale(iris[['sepal_length','sepal_width','petal_length',
                                              'petal_width']])
# Out:
# array([[-9.00681170e-01,  1.03205722e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00, -1.24957601e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.38535265e+00,  3.37848329e-01, -1.39813811e+00,
#         -1.31297673e+00],
#        [-1.50652052e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.02184904e+00,  1.26346019e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-5.37177559e-01,  1.95766909e+00, -1.17067529e+00,
#         -1.05003079e+00],
#        [-1.50652052e+00,  8.00654259e-01, -1.34127240e+00,
#         -1.18150376e+00],
#        [-1.02184904e+00,  8.00654259e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.74885626e+00, -3.56360566e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.44444970e+00],
#        [-5.37177559e-01,  1.49486315e+00, -1.28440670e+00,
#         -1.31297673e+00],
# ...

# %%
pd.DataFrame(
    preprocessing.scale(iris[['sepal_length','sepal_width','petal_length',
                                              'petal_width']])
)
# Out:
#             0         1         2         3
# 0   -0.900681  1.032057 -1.341272 -1.312977
# 1   -1.143017 -0.124958 -1.341272 -1.312977
# 2   -1.385353  0.337848 -1.398138 -1.312977
# 3   -1.506521  0.106445 -1.284407 -1.312977
# 4   -1.021849  1.263460 -1.341272 -1.312977
# ..        ...       ...       ...       ...
# 145  1.038005 -0.124958  0.819624  1.447956
# 146  0.553333 -1.281972  0.705893  0.922064
# 147  0.795669 -0.124958  0.819624  1.053537
# 148  0.432165  0.800654  0.933356  1.447956
# 149  0.068662 -0.124958  0.762759  0.790591
#
# [150 rows x 4 columns]

# %%
standardized_iris = pd.DataFrame(
    preprocessing.scale(iris[['sepal_length','sepal_width','petal_length',
                                              'petal_width']])
)
standardized_iris['species'] = iris['species']

# %%
standardized_iris
# Out:
#             0         1         2         3    species
# 0   -0.900681  1.032057 -1.341272 -1.312977     setosa
# 1   -1.143017 -0.124958 -1.341272 -1.312977     setosa
# 2   -1.385353  0.337848 -1.398138 -1.312977     setosa
# 3   -1.506521  0.106445 -1.284407 -1.312977     setosa
# 4   -1.021849  1.263460 -1.341272 -1.312977     setosa
# ..        ...       ...       ...       ...        ...
# 145  1.038005 -0.124958  0.819624  1.447956  virginica
# 146  0.553333 -1.281972  0.705893  0.922064  virginica
# 147  0.795669 -0.124958  0.819624  1.053537  virginica
# 148  0.432165  0.800654  0.933356  1.447956  virginica
# 149  0.068662 -0.124958  0.762759  0.790591  virginica
#
# [150 rows x 5 columns]

# %%
standardized_iris.columns = iris.columns

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
standardized_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0       -0.900681     1.032057     -1.341272    -1.312977     setosa
# 1       -1.143017    -0.124958     -1.341272    -1.312977     setosa
# 2       -1.385353     0.337848     -1.398138    -1.312977     setosa
# 3       -1.506521     0.106445     -1.284407    -1.312977     setosa
# 4       -1.021849     1.263460     -1.341272    -1.312977     setosa
# ..            ...          ...           ...          ...        ...
# 145      1.038005    -0.124958      0.819624     1.447956  virginica
# 146      0.553333    -1.281972      0.705893     0.922064  virginica
# 147      0.795669    -0.124958      0.819624     1.053537  virginica
# 148      0.432165     0.800654      0.933356     1.447956  virginica
# 149      0.068662    -0.124958      0.762759     0.790591  virginica
#
# [150 rows x 5 columns]

# %%
np.round(standardized_iris['sepal_length'].mean(axis = 0))
# Out:
# -0.0

# %%
np.round(standardized_iris['sepal_length'].std(axis = 0))
# Out:
# 1.0

# %%
standardized_iris.describe()
# Out:
#        sepal_length   sepal_width  petal_length   petal_width
# count  1.500000e+02  1.500000e+02  1.500000e+02  1.500000e+02
# mean  -2.775558e-16 -5.140333e-16  1.154632e-16  9.251859e-16
# std    1.003350e+00  1.003350e+00  1.003350e+00  1.003350e+00
# min   -1.870024e+00 -2.438987e+00 -1.568735e+00 -1.444450e+00
# 25%   -9.006812e-01 -5.877635e-01 -1.227541e+00 -1.181504e+00
# 50%   -5.250608e-02 -1.249576e-01  3.362659e-01  1.332259e-01
# 75%    6.745011e-01  5.692513e-01  7.627586e-01  7.905908e-01
# max    2.492019e+00  3.114684e+00  1.786341e+00  1.710902e+00

# %%
sns.violinplot(data = standardized_iris, x = 'species', y = 'sepal_length')
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# ### Extra Material: Difference Between Rows

# %%
data = pd.DataFrame({'penjualan':[1,2,4,5,8,10,12,15,18,20,25,19,17,12
                                 ]})

# %%
data
# Out:
#     penjualan
# 0           1
# 1           2
# 2           4
# 3           5
# 4           8
# 5          10
# 6          12
# 7          15
# 8          18
# 9          20
# 10         25
# 11         19
# 12         17
# 13         12

# %%
data['selisih_dari_hari_kemarin'] = data['penjualan'].diff()

# %%
data
# Out:
#     penjualan  selisih_dari_hari_kemarin
# 0           1                        NaN
# 1           2                        1.0
# 2           4                        2.0
# 3           5                        1.0
# 4           8                        3.0
# 5          10                        2.0
# 6          12                        2.0
# 7          15                        3.0
# 8          18                        3.0
# 9          20                        2.0
# 10         25                        5.0
# 11         19                       -6.0
# 12         17                       -2.0
# 13         12                       -5.0

# %%
data['selisih_dari_dua_hari_lalu'] = data['penjualan'].diff(2)

# %%
data
# Out:
#     penjualan  selisih_dari_hari_kemarin  selisih_dari_dua_hari_lalu
# 0           1                        NaN                         NaN
# 1           2                        1.0                         NaN
# 2           4                        2.0                         3.0
# 3           5                        1.0                         3.0
# 4           8                        3.0                         4.0
# 5          10                        2.0                         5.0
# 6          12                        2.0                         4.0
# 7          15                        3.0                         5.0
# 8          18                        3.0                         6.0
# 9          20                        2.0                         5.0
# 10         25                        5.0                         7.0
# 11         19                       -6.0                        -1.0
# 12         17                       -2.0                        -8.0
# ...
