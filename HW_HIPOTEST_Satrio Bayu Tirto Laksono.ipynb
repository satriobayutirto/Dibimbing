# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_sumber = pd.read_csv('/content/drive/MyDrive/data_assignment.csv')

# %%
data_sumber
# Out:
#     weight_kg
# 0        23.0
# 1        16.0
# 2        24.0
# 3        25.0
# 4        25.0
# 5        22.5
# 6        21.0
# 7        29.5
# 8        19.5
# 9        18.5
# 10       22.5
# 11       24.5
# 12       23.0
# 13       26.5
# 14       27.0
# 15       27.5
# 16       25.5
# 17       25.0
# 18       23.0
# 19       27.0
# 20       28.0
# 21       28.5
# 22       22.5
# 23       22.5
# 24       21.0
# 25       19.0
# 26       19.5
# 27       29.0
# 28       30.0
# 29       30.5
# 30       31.0
# 31       31.0
# 32       30.0
# 33       22.0
# 34       19.0
# 35       19.5
# 36       15.0
# 37       24.0
# 38       25.5
# 39       23.5
# 40       26.0
# 41       27.5
# 42       25.0
# 43       25.0
# 44       25.0
# 45       26.5
# 46       24.5
# 47       10.0
# 48       15.5
# 49       35.0
# 50       30.5
# 51       29.0
# 52       24.5
# 53       24.0
# 54       19.0
# 55       18.5
# 56       17.0
# 57       17.0
# 58       25.0

# %% [markdown]
# Summary Statistic (mean, media)

# %%
data_sumber.mode()
# Out:
#    weight_kg
# 0       25.0

# %%
x=data_sumber.mean()
med=data_sumber.median()
print (f'Mean {x} , Median {med}')
# Out:
# Mean weight_kg    23.915254
# dtype: float64 , Median weight_kg    24.5
# dtype: float64

# %% [markdown]
# Box plot

# %%
plt.boxplot(data_sumber)
plt.show()

# %% [markdown]
# Histogram

# %%
plt.hist(data_sumber)
plt.show()

# %% [markdown]
# Ksimpulan
#
# q1=21 q3 = 27 median = 25 outer=1 buah

# %% [markdown]
# Uji T test apakah rata rata berat tikus =25 kg

# %%
stats.describe(data_sumber)
# Out:
# DescribeResult(nobs=59, minmax=(array([10.]), array([35.])), mean=array([23.91525424]), variance=array([22.49269433]), skewness=array([-0.3668265]), kurtosis=array([0.20398619]))

# %%
stats.ttest_1samp(data_sumber, popmean =25)
# Out:
# TtestResult(statistic=array([-1.75684411]), pvalue=array([0.08422228]), df=array([58]))

# %% [markdown]
# Kesimpulan
#
# H0: μ = 25
#
# H1: μ ≠ 25
#
# p value lebih besar dari 0.05, sehingga H0 diterima dan H1 ditolak.
