# %%
nums1 = [1, 2, 3, 0, 0, 0]
m = 3
nums2 = [2, 5, 6]
n = 3

nums1[m:] = nums2[:n]
nums1.sort()

print(nums1)

by eud sugianto batch 24
# Out:
# [1, 2, 2, 3, 5, 6]

# %%
def group_anagrams(strs):
    anagram_groups = {}

    for word in strs:
        # Sort the characters in the word to create a unique key
        sorted_word = ''.join(sorted(word))

        # Check if the key is already in the dictionary
        if sorted_word in anagram_groups:
            anagram_groups[sorted_word].append(word)
        else:
            # If the key is not in the dictionary, create a new entry
            anagram_groups[sorted_word] = [word]

    return list(anagram_groups.values())

# %%
nums1 = [1,2,2,1]
nums2 = [2,2]
     nums1 = [1,2,2,1]
nums2 = [2,2]
      same_value=[]
        for number in nums1:
            if number in nums2:
                same_value.append(number)
        unique=list(set(same_value))
        print(unique)
# Out:
#   File "<ipython-input-7-cfe13876362e>", line 3
#     same_value=()
#     ^
# IndentationError: unexpected indent

# %%
chat gpt
nums1 = [1, 2, 2, 1]
nums2 = [2, 2]

# Finding common elements and creating a list of unique values
unique_common_elements = list(set(nums1) & set(nums2))
return unique_common_elements
print(unique_common_elements)
# Out:
# [2]

# %%
solution
dictionary = {}
        for index in nums1:
            if index not in dictionary:
                dictionary[index] = 1
        for index in nums2:
            if index in dictionary and dictionary[index] != 2:
                dictionary[index] += 1
        newList = []
        for key, value in dictionary.items():
            if value == 2:
                newList.append(key)

        return newList

# %%
 from math import log
x=log(243,3)
round(x)==5
# Out:
# True

# %%
a=3**18
a
# Out:
# 387420489

# %%
n= 387420489
if n > 0 == 3**88% n:
  print(True)
else:
  print(False)

f=3**19 % n
a=3**19
print(f'{a} % {n} = {f}')
# Out:
# True
# 1162261467 % 387420489 = 0
